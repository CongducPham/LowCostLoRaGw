# %% [markdown]
# ## Importing the file
#
# I've imported the data and add 2 more columns to make it easier to query in the future when I'm creating different dataframes for different fields.

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('Train.csv')

# Filling the empty cells for Irrigation
df['Irrigation field 1'].fillna(0, inplace=True)
df['Irrigation field 2'].fillna(0, inplace=True)
df['Irrigation field 3'].fillna(0, inplace=True)
df['Irrigation field 4'].fillna(0, inplace=True)


# Putting a column to make it easier to differentiate train and test data
def train_test(cols):
    temp = cols[0]
    
    if pd.isnull(temp): return 1
    else: return 0
    
df['train_test'] = df[['Air temperature (C)']].apply(train_test,axis=1)

# I've put this column to make it easier to arrange dataframes for different fields
def segmentation(cols):
    date = cols[0]
    
    if date<=10066: return 1
    elif date<=17235: return 2
    else: return 3

df.reset_index(inplace=True)
    
df['segmentation'] = df[['index']].apply(segmentation,axis=1)

df.head()
# Out:
#    index            timestamp  Soil humidity 1  Irrigation field 1  \
# 0      0  2019-02-23 00:00:00            67.92                 0.0
# 1      1  2019-02-23 00:05:00            67.89                 0.0
# 2      2  2019-02-23 00:10:00            67.86                 0.0
# 3      3  2019-02-23 00:15:00            67.84                 0.0
# 4      4  2019-02-23 00:20:00            67.81                 0.0
#
#    Soil humidity 2  Irrigation field 2  Soil humidity 3  Irrigation field 3  \
# 0            55.72                 0.0            -1.56                 1.0
# 1            55.74                 0.0            -1.51                 1.0
# 2            55.77                 0.0            -1.47                 1.0
# 3            55.79                 0.0            -1.42                 1.0
# 4            55.82                 0.0            -1.38                 1.0
#
#    Soil humidity 4  Irrigation field 4  Air temperature (C)  Air humidity (%)  \
# 0            26.57                 1.0                19.52             55.04
# 1            26.58                 1.0                19.49             55.17
# 2            26.59                 1.0                19.47             55.30
# 3            26.61                 1.0                19.54             54.20
# 4            26.62                 1.0                19.61             53.09
#
#    Pressure (KPa)  Wind speed (Km/h)  Wind gust (Km/h)  Wind direction (Deg)  \
# 0          101.50               2.13              6.30                225.00
# 1          101.50               2.01             10.46                123.75
# 2          101.51               1.90             14.63                 22.50
# 3          101.51               2.28             16.08                123.75
# 4          101.51               2.66             17.52                225.00
#
#    train_test  segmentation
# 0           0             1
# 1           0             1
# 2           0             1
# 3           0             1
# 4           0             1

# %% [markdown]
# ## Updating the values of test data days with the previous date
#
# I didn't do any ARIMA or time-series model to predict the climate values of test dates. I've just copied the last day's values as test data.

# %%
import warnings
warnings.filterwarnings('ignore')

liste = ['Air temperature (C)','Air humidity (%)','Pressure (KPa)','Wind speed (Km/h)','Wind gust (Km/h)',
         'Wind direction (Deg)']

for item in liste:
    
    i = 8914
    i_max = 10066
    while i<=i_max:
        df[item][i] = df[item][i-288]
        i = i+1
    print(item+' 1')

    i = 16083 
    i_max = 17235
    while i<=i_max:
        df[item][i] = df[item][i-288]
        i = i+1
    print(item+' 2')

    i = 26301  
    i_max = 28029
    while i<=i_max:
        df[item][i] = df[item][i-288]
        i = i+1
    print(item+' 3')
# Out:
# Air temperature (C) 1
# Air temperature (C) 2
# Air temperature (C) 3
# Air humidity (%) 1
# Air humidity (%) 2
# Air humidity (%) 3
# Pressure (KPa) 1
# Pressure (KPa) 2
# Pressure (KPa) 3
# Wind speed (Km/h) 1
# Wind speed (Km/h) 2
# Wind speed (Km/h) 3
# Wind gust (Km/h) 1
# Wind gust (Km/h) 2
# Wind gust (Km/h) 3
# Wind direction (Deg) 1
# Wind direction (Deg) 2
# Wind direction (Deg) 3

# %% [markdown]
# I've created the target column as average difference between 5 consecutive records. My model will try to predict these values.
#
# I've also create a time column to show the time.

# %%
df['target_1'] = (df['Soil humidity 1'] - df['Soil humidity 1'].shift(5))/5
df['target_2'] = (df['Soil humidity 2'] - df['Soil humidity 2'].shift(5))/5
df['target_3'] = (df['Soil humidity 3'] - df['Soil humidity 3'].shift(5))/5
df['target_4'] = (df['Soil humidity 4'] - df['Soil humidity 4'].shift(5))/5

df['time'] = df.timestamp.str.slice(11,13).astype(int) * 100 +df.timestamp.str.slice(14,16).astype(int)

# %% [markdown]
# ## Creating train and test dataframes
#
# I've decided to model for the irrigation on and off situations seperately. So for each field, I've created 1 "irrigation on" and 1 "irrigation off" train and test dataframes.
#
# In the next part I will train the model both with these dataframes and make the predictions accordingly.
#
# So my model will be able to say "if the irrigation is on, this field is gaining humidity with x.xx%, if the irrigation is off the field is losing humidity with x.xx%".

# %%
#### FIELD 1
liste = ['index','timestamp','target_1','Irrigation field 1','Air temperature (C)','Air humidity (%)','Pressure (KPa)',
         'Wind speed (Km/h)','Wind gust (Km/h)','Wind direction (Deg)','time']

df_1_train_on = df[liste][(df['segmentation']<=1) & (df['train_test']==0) & (df['Irrigation field 1']==1)]
df_1_train_on.dropna(inplace=True)
df_1_train_on.rename(columns={'target_1': 'target', 'Irrigation field 1': 'Irrigation'}, inplace=True)

df_1_test_on = df[liste][(df['segmentation']==1) & (df['train_test']==1) & (df['Irrigation field 1']==1)]
df_1_test_on.rename(columns={'target_1': 'target', 'Irrigation field 1': 'Irrigation'}, inplace=True)
df_1_test_on.fillna(0, inplace=True)

df_1_train_off = df[liste][(df['segmentation']<=1) & (df['train_test']==0) & (df['Irrigation field 1']==0)]
df_1_train_off.dropna(inplace=True)
df_1_train_off.rename(columns={'target_1': 'target', 'Irrigation field 1': 'Irrigation'}, inplace=True)

df_1_test_off = df[liste][(df['segmentation']==1) & (df['train_test']==1) & (df['Irrigation field 1']==0)]
df_1_test_off.rename(columns={'target_1': 'target', 'Irrigation field 1': 'Irrigation'}, inplace=True)
df_1_test_off.fillna(0, inplace=True)


#### FIELD 2
liste = ['index','timestamp','target_2','Irrigation field 2','Air temperature (C)','Air humidity (%)','Pressure (KPa)',
         'Wind speed (Km/h)','Wind gust (Km/h)','Wind direction (Deg)','time']

df_2_train_on = df[liste][(df['segmentation']<=3) & (df['train_test']==0) & (df['Irrigation field 2']==1)]
df_2_train_on.dropna(inplace=True)
df_2_train_on.rename(columns={'target_2': 'target', 'Irrigation field 2': 'Irrigation'}, inplace=True)

df_2_test_on = df[liste][(df['segmentation']==3) & (df['train_test']==1) & (df['Irrigation field 2']==1)]
df_2_test_on.rename(columns={'target_2': 'target', 'Irrigation field 2': 'Irrigation'}, inplace=True)
df_2_test_on.fillna(0, inplace=True)

df_2_train_off = df[liste][(df['segmentation']<=3) & (df['train_test']==0) & (df['Irrigation field 2']==0)]
df_2_train_off.dropna(inplace=True)
df_2_train_off.rename(columns={'target_2': 'target', 'Irrigation field 2': 'Irrigation'}, inplace=True)

df_2_test_off = df[liste][(df['segmentation']==3) & (df['train_test']==1) & (df['Irrigation field 2']==0)]
df_2_test_off.rename(columns={'target_2': 'target', 'Irrigation field 2': 'Irrigation'}, inplace=True)
df_2_test_off.fillna(0, inplace=True)


#### FIELD 3
liste = ['index','timestamp','target_3','Irrigation field 3','Air temperature (C)','Air humidity (%)','Pressure (KPa)',
         'Wind speed (Km/h)','Wind gust (Km/h)','Wind direction (Deg)','time']

df_3_train_on = df[liste][(df['segmentation']<=2) & (df['train_test']==0) & (df['Irrigation field 3']==1)]
df_3_train_on.dropna(inplace=True)
df_3_train_on.rename(columns={'target_3': 'target', 'Irrigation field 3': 'Irrigation'}, inplace=True)

df_3_test_on = df[liste][(df['segmentation']==2) & (df['train_test']==1) & (df['Irrigation field 3']==1)]
df_3_test_on.rename(columns={'target_3': 'target', 'Irrigation field 3': 'Irrigation'}, inplace=True)
df_3_test_on.fillna(0, inplace=True)

df_3_train_off = df[liste][(df['segmentation']<=2) & (df['train_test']==0) & (df['Irrigation field 3']==0)]
df_3_train_off.dropna(inplace=True)
df_3_train_off.rename(columns={'target_3': 'target', 'Irrigation field 3': 'Irrigation'}, inplace=True)

df_3_test_off = df[liste][(df['segmentation']==2) & (df['train_test']==1) & (df['Irrigation field 3']==0)]
df_3_test_off.rename(columns={'target_3': 'target', 'Irrigation field 3': 'Irrigation'}, inplace=True)
df_3_test_off.fillna(0, inplace=True)


#### FIELD 4
liste = ['index','timestamp','target_4','Irrigation field 4','Air temperature (C)','Air humidity (%)','Pressure (KPa)',
         'Wind speed (Km/h)','Wind gust (Km/h)','Wind direction (Deg)','time']

df_4_train_on = df[liste][(df['segmentation']<=3) & (df['train_test']==0) & (df['Irrigation field 4']==1)]
df_4_train_on.dropna(inplace=True)
df_4_train_on.rename(columns={'target_4': 'target', 'Irrigation field 4': 'Irrigation'}, inplace=True)

df_4_test_on = df[liste][(df['segmentation']==3) & (df['train_test']==1) & (df['Irrigation field 4']==1)]
df_4_test_on.rename(columns={'target_4': 'target', 'Irrigation field 4': 'Irrigation'}, inplace=True)
df_4_test_on.fillna(0, inplace=True)

df_4_train_off = df[liste][(df['segmentation']<=3) & (df['train_test']==0) & (df['Irrigation field 4']==0)]
df_4_train_off.dropna(inplace=True)
df_4_train_off.rename(columns={'target_4': 'target', 'Irrigation field 4': 'Irrigation'}, inplace=True)

df_4_test_off = df[liste][(df['segmentation']==3) & (df['train_test']==1) & (df['Irrigation field 4']==0)]
df_4_test_off.rename(columns={'target_4': 'target', 'Irrigation field 4': 'Irrigation'}, inplace=True)
df_4_test_off.fillna(0, inplace=True)

# %% [markdown]
# ## Model
#
# I've used a simple XGBRegressor with following parameters (n_estimators=100, booster='dart')
#
# I've trained the same model seperately for each field and for irrigation on/off cases.

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

model_xgb = XGBRegressor(n_estimators=100, booster='dart')


##################################### FIELD 1 #####################################
df_on = df_1_train_on[df_1_train_on['target']>=0.05]

outcomes = df_on[['index','timestamp','target']].copy()
features = df_on.drop(['index','timestamp','target'], axis = 1).copy()

y_test = df_1_test_on[['index','timestamp','target']].copy()
X_test = df_1_test_on.drop(['index','timestamp','target'], axis = 1).copy()

# Train - Valid seperation
X_train, X_valid, y_train, y_valid = train_test_split(features, outcomes, test_size=0.25, random_state=42)

model_xgb.fit(X_train, y_train['target'], verbose=True, eval_metric='rmse',
              eval_set=[(X_train, y_train['target']), (X_valid, y_valid['target'])])

predictions_xgb_1_on = model_xgb.predict(X_test)

oran_real = df_1_train_on['target'].mean()
oran_predictions = predictions_xgb_1_on.mean()

deneme = model_xgb.predict(X_train)
error_1_on = mean_squared_error(y_train['target'],deneme)
error_1_on_fixed = mean_squared_error(y_train['target'],deneme * oran_real / oran_predictions)

##########
df_off = df_1_train_off[df_1_train_off['target']<0]

outcomes = df_off[['index','timestamp','target']].copy()
features = df_off.drop(['index','timestamp','target'], axis = 1).copy()

y_test = df_1_test_off[['index','timestamp','target']].copy()
X_test = df_1_test_off.drop(['index','timestamp','target'], axis = 1).copy()

# Train - Valid seperation
X_train, X_valid, y_train, y_valid = train_test_split(features, outcomes, test_size=0.25, random_state=42)

model_xgb.fit(X_train, y_train['target'], verbose=True, eval_metric='rmse',
              eval_set=[(X_train, y_train['target']), (X_valid, y_valid['target'])])

predictions_xgb_1_off = model_xgb.predict(X_test)

oran_real = df_1_train_off['target'].mean()
oran_predictions = predictions_xgb_1_off.mean()

deneme = model_xgb.predict(X_train)
error_1_off = mean_squared_error(y_train['target'],deneme)
error_1_off_fixed = mean_squared_error(y_train['target'],deneme * oran_real / oran_predictions)


##################################### FIELD 2 #####################################
df_on = df_2_train_on[df_2_train_on['target']>=0.05]

outcomes = df_on[['index','timestamp','target']].copy()
features = df_on.drop(['index','timestamp','target'], axis = 1).copy()

y_test = df_2_test_on[['index','timestamp','target']].copy()
X_test = df_2_test_on.drop(['index','timestamp','target'], axis = 1).copy()

# Train - Valid seperation
X_train, X_valid, y_train, y_valid = train_test_split(features, outcomes, test_size=0.25, random_state=42)

model_xgb.fit(X_train, y_train['target'], verbose=True, eval_metric='rmse',
              eval_set=[(X_train, y_train['target']), (X_valid, y_valid['target'])])

predictions_xgb_2_on = model_xgb.predict(X_test)

oran_real = df_2_train_on['target'].mean()
oran_predictions = predictions_xgb_2_on.mean()

deneme = model_xgb.predict(X_train)
error_2_on = mean_squared_error(y_train['target'],deneme)
error_2_on_fixed = mean_squared_error(y_train['target'],deneme * oran_real / oran_predictions)

##########
df_off = df_2_train_off[df_2_train_off['target']<0]

outcomes = df_off[['index','timestamp','target']].copy()
features = df_off.drop(['index','timestamp','target'], axis = 1).copy()

y_test = df_2_test_off[['index','timestamp','target']].copy()
X_test = df_2_test_off.drop(['index','timestamp','target'], axis = 1).copy()

# Train - Valid seperation
X_train, X_valid, y_train, y_valid = train_test_split(features, outcomes, test_size=0.25, random_state=42)

model_xgb.fit(X_train, y_train['target'], verbose=True, eval_metric='rmse',
              eval_set=[(X_train, y_train['target']), (X_valid, y_valid['target'])])

predictions_xgb_2_off = model_xgb.predict(X_test)

oran_real = df_2_train_off['target'].mean()
oran_predictions = predictions_xgb_2_off.mean()

deneme = model_xgb.predict(X_train)
error_2_off = mean_squared_error(y_train['target'],deneme)
error_2_off_fixed = mean_squared_error(y_train['target'],deneme * oran_real / oran_predictions)


##################################### FIELD 3 #####################################
df_on = df_3_train_on[df_3_train_on['target']>=0.05]

outcomes = df_on[['index','timestamp','target']].copy()
features = df_on.drop(['index','timestamp','target'], axis = 1).copy()

y_test = df_3_test_on[['index','timestamp','target']].copy()
X_test = df_3_test_on.drop(['index','timestamp','target'], axis = 1).copy()

# Train - Valid seperation
X_train, X_valid, y_train, y_valid = train_test_split(features, outcomes, test_size=0.25, random_state=42)

model_xgb.fit(X_train, y_train['target'], verbose=True, eval_metric='rmse',
              eval_set=[(X_train, y_train['target']), (X_valid, y_valid['target'])])

predictions_xgb_3_on = model_xgb.predict(X_test)

oran_real = df_3_train_on['target'].mean()
oran_predictions = predictions_xgb_3_on.mean()

deneme = model_xgb.predict(X_train)
error_3_on = mean_squared_error(y_train['target'],deneme)
error_3_on_fixed = mean_squared_error(y_train['target'],deneme * oran_real / oran_predictions)

##########
df_off = df_3_train_off[df_3_train_off['target']<0]

outcomes = df_off[['index','timestamp','target']].copy()
features = df_off.drop(['index','timestamp','target'], axis = 1).copy()

y_test = df_3_test_off[['index','timestamp','target']].copy()
X_test = df_3_test_off.drop(['index','timestamp','target'], axis = 1).copy()

# Train - Valid seperation
X_train, X_valid, y_train, y_valid = train_test_split(features, outcomes, test_size=0.25, random_state=42)

model_xgb.fit(X_train, y_train['target'], verbose=True, eval_metric='rmse',
              eval_set=[(X_train, y_train['target']), (X_valid, y_valid['target'])])

predictions_xgb_3_off = model_xgb.predict(X_test)

oran_real = df_3_train_off['target'].mean()
oran_predictions = predictions_xgb_3_off.mean()

deneme = model_xgb.predict(X_train)
error_3_off = mean_squared_error(y_train['target'],deneme)
error_3_off_fixed = mean_squared_error(y_train['target'],deneme * oran_real / oran_predictions)


##################################### FIELD 4 #####################################
df_on = df_4_train_on[df_4_train_on['target']>=0.05]

outcomes = df_on[['index','timestamp','target']].copy()
features = df_on.drop(['index','timestamp','target'], axis = 1).copy()

y_test = df_4_test_on[['index','timestamp','target']].copy()
X_test = df_4_test_on.drop(['index','timestamp','target'], axis = 1).copy()

# Train - Valid seperation
X_train, X_valid, y_train, y_valid = train_test_split(features, outcomes, test_size=0.25, random_state=42)

model_xgb.fit(X_train, y_train['target'], verbose=True, eval_metric='rmse',
              eval_set=[(X_train, y_train['target']), (X_valid, y_valid['target'])])

predictions_xgb_4_on = model_xgb.predict(X_test)

oran_real = df_4_train_on['target'].mean()
oran_predictions = predictions_xgb_4_on.mean()

deneme = model_xgb.predict(X_train)
error_4_on = mean_squared_error(y_train['target'],deneme)
error_4_on_fixed = mean_squared_error(y_train['target'],deneme * oran_real / oran_predictions)

##########
df_off = df_4_train_off[df_4_train_off['target']<0]

outcomes = df_off[['index','timestamp','target']].copy()
features = df_off.drop(['index','timestamp','target'], axis = 1).copy()

y_test = df_4_test_off[['index','timestamp','target']].copy()
X_test = df_4_test_off.drop(['index','timestamp','target'], axis = 1).copy()

# Train - Valid seperation
X_train, X_valid, y_train, y_valid = train_test_split(features, outcomes, test_size=0.25, random_state=42)

model_xgb.fit(X_train, y_train['target'], verbose=True, eval_metric='rmse',
              eval_set=[(X_train, y_train['target']), (X_valid, y_valid['target'])])

predictions_xgb_4_off = model_xgb.predict(X_test)

oran_real = df_4_train_off['target'].mean()
oran_predictions = predictions_xgb_4_off.mean()

deneme = model_xgb.predict(X_train)
error_4_off = mean_squared_error(y_train['target'],deneme)
error_4_off_fixed = mean_squared_error(y_train['target'],deneme * oran_real / oran_predictions)


#####################

print("Error 1 on : "+str(round(error_1_on,6))+" - "+str(round(error_1_on_fixed,6)))
print("Error 1 off: "+str(round(error_1_off,6))+" - "+str(round(error_1_off_fixed,6)))
print("Error 2 on : "+str(round(error_2_on,6))+" - "+str(round(error_2_on_fixed,6)))
print("Error 2 off: "+str(round(error_2_off,6))+" - "+str(round(error_2_off_fixed,6)))
print("Error 3 on : "+str(round(error_3_on,6))+" - "+str(round(error_3_on_fixed,6)))
print("Error 3 off: "+str(round(error_3_off,6))+" - "+str(round(error_3_off_fixed,6)))
print("Error 4 on : "+str(round(error_4_on,6))+" - "+str(round(error_4_on_fixed,6)))
print("Error 4 off: "+str(round(error_4_off,6))+" - "+str(round(error_4_off_fixed,6)))
# Out:
# [11:40:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:0.338469	validation_1-rmse:0.332912
# [1]	validation_0-rmse:0.307234	validation_1-rmse:0.302122
# [2]	validation_0-rmse:0.277905	validation_1-rmse:0.273288
# [3]	validation_0-rmse:0.251771	validation_1-rmse:0.247889
# [4]	validation_0-rmse:0.22796	validation_1-rmse:0.225471
# [5]	validation_0-rmse:0.207305	validation_1-rmse:0.205674
# [6]	validation_0-rmse:0.188868	validation_1-rmse:0.187714
# [7]	validation_0-rmse:0.171436	validation_1-rmse:0.171457
# [8]	validation_0-rmse:0.15644	validation_1-rmse:0.157378
# [9]	validation_0-rmse:0.141984	validation_1-rmse:0.143505
# [10]	validation_0-rmse:0.129293	validation_1-rmse:0.1322
# [11]	validation_0-rmse:0.117984	validation_1-rmse:0.121959
# [12]	validation_0-rmse:0.108444	validation_1-rmse:0.113341
# [13]	validation_0-rmse:0.099268	validation_1-rmse:0.104692
# [14]	validation_0-rmse:0.091377	validation_1-rmse:0.097376
# [15]	validation_0-rmse:0.084036	validation_1-rmse:0.090752
# [16]	validation_0-rmse:0.077466	validation_1-rmse:0.084755
# [17]	validation_0-rmse:0.071247	validation_1-rmse:0.079649
# [18]	validation_0-rmse:0.066217	validation_1-rmse:0.075655
# [19]	validation_0-rmse:0.061777	validation_1-rmse:0.071908
# [20]	validation_0-rmse:0.057549	validation_1-rmse:0.068227
# [21]	validation_0-rmse:0.053761	validation_1-rmse:0.06517
# [22]	validation_0-rmse:0.050638	validation_1-rmse:0.062656
# [23]	validation_0-rmse:0.047719	validation_1-rmse:0.060211
# [24]	validation_0-rmse:0.045169	validation_1-rmse:0.058481
# [25]	validation_0-rmse:0.042755	validation_1-rmse:0.05668
# [26]	validation_0-rmse:0.040813	validation_1-rmse:0.05522
# [27]	validation_0-rmse:0.039075	validation_1-rmse:0.053848
# [28]	validation_0-rmse:0.037513	validation_1-rmse:0.05293
# [29]	validation_0-rmse:0.03546	validation_1-rmse:0.051741
# [30]	validation_0-rmse:0.034243	validation_1-rmse:0.050887
# [31]	validation_0-rmse:0.03284	validation_1-rmse:0.04989
# [32]	validation_0-rmse:0.031857	validation_1-rmse:0.049153
# [33]	validation_0-rmse:0.030706	validation_1-rmse:0.04855
# [34]	validation_0-rmse:0.029682	validation_1-rmse:0.047857
# [35]	validation_0-rmse:0.028795	validation_1-rmse:0.047437
# [36]	validation_0-rmse:0.02798	validation_1-rmse:0.046801
# [37]	validation_0-rmse:0.027355	validation_1-rmse:0.046334
# [38]	validation_0-rmse:0.026555	validation_1-rmse:0.046001
# [39]	validation_0-rmse:0.025918	validation_1-rmse:0.045523
# [40]	validation_0-rmse:0.025416	validation_1-rmse:0.045182
# [41]	validation_0-rmse:0.024957	validation_1-rmse:0.044912
# [42]	validation_0-rmse:0.02448	validation_1-rmse:0.044642
# [43]	validation_0-rmse:0.024125	validation_1-rmse:0.044383
# [44]	validation_0-rmse:0.023709	validation_1-rmse:0.044068
# [45]	validation_0-rmse:0.023116	validation_1-rmse:0.043611
# [46]	validation_0-rmse:0.022758	validation_1-rmse:0.043344
# [47]	validation_0-rmse:0.022413	validation_1-rmse:0.043142
# [48]	validation_0-rmse:0.022053	validation_1-rmse:0.042802
# [49]	validation_0-rmse:0.021591	validation_1-rmse:0.042447
# [50]	validation_0-rmse:0.021273	validation_1-rmse:0.042316
# [51]	validation_0-rmse:0.021003	validation_1-rmse:0.042226
# [52]	validation_0-rmse:0.020741	validation_1-rmse:0.042078
# [53]	validation_0-rmse:0.020397	validation_1-rmse:0.041755
# [54]	validation_0-rmse:0.020208	validation_1-rmse:0.041631
# [55]	validation_0-rmse:0.019887	validation_1-rmse:0.041369
# [56]	validation_0-rmse:0.019672	validation_1-rmse:0.041218
# [57]	validation_0-rmse:0.019245	validation_1-rmse:0.040949
# [58]	validation_0-rmse:0.01906	validation_1-rmse:0.040819
# [59]	validation_0-rmse:0.018857	validation_1-rmse:0.040663
# [60]	validation_0-rmse:0.018556	validation_1-rmse:0.040431
# [61]	validation_0-rmse:0.018203	validation_1-rmse:0.040219
# [62]	validation_0-rmse:0.017973	validation_1-rmse:0.040052
# [63]	validation_0-rmse:0.017792	validation_1-rmse:0.039966
# [64]	validation_0-rmse:0.017309	validation_1-rmse:0.039762
# [65]	validation_0-rmse:0.017089	validation_1-rmse:0.03961
# [66]	validation_0-rmse:0.016837	validation_1-rmse:0.039467
# [67]	validation_0-rmse:0.016455	validation_1-rmse:0.039324
# [68]	validation_0-rmse:0.016276	validation_1-rmse:0.039231
# [69]	validation_0-rmse:0.016123	validation_1-rmse:0.03918
# [70]	validation_0-rmse:0.015825	validation_1-rmse:0.039139
# [71]	validation_0-rmse:0.015712	validation_1-rmse:0.039106
# [72]	validation_0-rmse:0.015455	validation_1-rmse:0.039069
# [73]	validation_0-rmse:0.015356	validation_1-rmse:0.039066
# [74]	validation_0-rmse:0.015147	validation_1-rmse:0.039035
# [75]	validation_0-rmse:0.01503	validation_1-rmse:0.038951
# [76]	validation_0-rmse:0.014748	validation_1-rmse:0.038818
# [77]	validation_0-rmse:0.014488	validation_1-rmse:0.038711
# [78]	validation_0-rmse:0.0143	validation_1-rmse:0.038631
# [79]	validation_0-rmse:0.014209	validation_1-rmse:0.038622
# [80]	validation_0-rmse:0.014103	validation_1-rmse:0.03858
# [81]	validation_0-rmse:0.014028	validation_1-rmse:0.038562
# [82]	validation_0-rmse:0.013952	validation_1-rmse:0.038561
# [83]	validation_0-rmse:0.013827	validation_1-rmse:0.038511
# [84]	validation_0-rmse:0.013691	validation_1-rmse:0.038507
# [85]	validation_0-rmse:0.013626	validation_1-rmse:0.038489
# [86]	validation_0-rmse:0.013522	validation_1-rmse:0.038438
# [87]	validation_0-rmse:0.013425	validation_1-rmse:0.038402
# [88]	validation_0-rmse:0.013334	validation_1-rmse:0.038374
# [89]	validation_0-rmse:0.013198	validation_1-rmse:0.038391
# [90]	validation_0-rmse:0.013118	validation_1-rmse:0.038385
# [91]	validation_0-rmse:0.013064	validation_1-rmse:0.038389
# [92]	validation_0-rmse:0.013034	validation_1-rmse:0.038396
# [93]	validation_0-rmse:0.012931	validation_1-rmse:0.038339
# [94]	validation_0-rmse:0.012816	validation_1-rmse:0.038287
# [95]	validation_0-rmse:0.012739	validation_1-rmse:0.038291
# [96]	validation_0-rmse:0.012722	validation_1-rmse:0.038295
# [97]	validation_0-rmse:0.012635	validation_1-rmse:0.038301
# [98]	validation_0-rmse:0.01262	validation_1-rmse:0.038301
# [99]	validation_0-rmse:0.012486	validation_1-rmse:0.038263
# [11:40:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:0.484863	validation_1-rmse:0.48532
# [1]	validation_0-rmse:0.436565	validation_1-rmse:0.437013
# [2]	validation_0-rmse:0.393106	validation_1-rmse:0.393589
# [3]	validation_0-rmse:0.354002	validation_1-rmse:0.354569
# [4]	validation_0-rmse:0.318823	validation_1-rmse:0.319424
# [5]	validation_0-rmse:0.287179	validation_1-rmse:0.287814
# [6]	validation_0-rmse:0.258711	validation_1-rmse:0.259401
# [7]	validation_0-rmse:0.233101	validation_1-rmse:0.233843
# [8]	validation_0-rmse:0.210075	validation_1-rmse:0.210919
# [9]	validation_0-rmse:0.189372	validation_1-rmse:0.190317
# [10]	validation_0-rmse:0.17075	validation_1-rmse:0.171744
# [11]	validation_0-rmse:0.154025	validation_1-rmse:0.155055
# [12]	validation_0-rmse:0.138996	validation_1-rmse:0.140046
# [13]	validation_0-rmse:0.12551	validation_1-rmse:0.126618
# [14]	validation_0-rmse:0.11341	validation_1-rmse:0.114573
# [15]	validation_0-rmse:0.102524	validation_1-rmse:0.103741
# [16]	validation_0-rmse:0.0928	validation_1-rmse:0.094105
# [17]	validation_0-rmse:0.084073	validation_1-rmse:0.085446
# [18]	validation_0-rmse:0.076238	validation_1-rmse:0.077648
# [19]	validation_0-rmse:0.069263	validation_1-rmse:0.070759
# [20]	validation_0-rmse:0.063011	validation_1-rmse:0.064532
# [21]	validation_0-rmse:0.057484	validation_1-rmse:0.059068
# [22]	validation_0-rmse:0.052539	validation_1-rmse:0.054186
# [23]	validation_0-rmse:0.048189	validation_1-rmse:0.049907
# [24]	validation_0-rmse:0.044315	validation_1-rmse:0.046101
# [25]	validation_0-rmse:0.04093	validation_1-rmse:0.042813
# [26]	validation_0-rmse:0.037848	validation_1-rmse:0.039753
# [27]	validation_0-rmse:0.035246	validation_1-rmse:0.037241
# [28]	validation_0-rmse:0.032895	validation_1-rmse:0.034979
# [29]	validation_0-rmse:0.030928	validation_1-rmse:0.033075
# [30]	validation_0-rmse:0.02916	validation_1-rmse:0.03135
# [31]	validation_0-rmse:0.027575	validation_1-rmse:0.029796
# [32]	validation_0-rmse:0.026274	validation_1-rmse:0.028542
# [33]	validation_0-rmse:0.025093	validation_1-rmse:0.027358
# [34]	validation_0-rmse:0.024165	validation_1-rmse:0.026467
# [35]	validation_0-rmse:0.023397	validation_1-rmse:0.025721
# [36]	validation_0-rmse:0.022628	validation_1-rmse:0.024943
# [37]	validation_0-rmse:0.022073	validation_1-rmse:0.024395
# [38]	validation_0-rmse:0.021577	validation_1-rmse:0.02392
# [39]	validation_0-rmse:0.021149	validation_1-rmse:0.023508
# [40]	validation_0-rmse:0.020808	validation_1-rmse:0.023182
# [41]	validation_0-rmse:0.020436	validation_1-rmse:0.022793
# [42]	validation_0-rmse:0.020168	validation_1-rmse:0.022535
# [43]	validation_0-rmse:0.019923	validation_1-rmse:0.022299
# [44]	validation_0-rmse:0.019754	validation_1-rmse:0.022126
# [45]	validation_0-rmse:0.019481	validation_1-rmse:0.021866
# [46]	validation_0-rmse:0.019316	validation_1-rmse:0.021697
# [47]	validation_0-rmse:0.019152	validation_1-rmse:0.021522
# [48]	validation_0-rmse:0.019013	validation_1-rmse:0.021388
# [49]	validation_0-rmse:0.018822	validation_1-rmse:0.021192
# [50]	validation_0-rmse:0.018712	validation_1-rmse:0.021068
# [51]	validation_0-rmse:0.018545	validation_1-rmse:0.020868
# [52]	validation_0-rmse:0.018462	validation_1-rmse:0.020801
# [53]	validation_0-rmse:0.018395	validation_1-rmse:0.020739
# [54]	validation_0-rmse:0.018265	validation_1-rmse:0.020592
# [55]	validation_0-rmse:0.018166	validation_1-rmse:0.020495
# [56]	validation_0-rmse:0.018091	validation_1-rmse:0.020426
# [57]	validation_0-rmse:0.018001	validation_1-rmse:0.020361
# [58]	validation_0-rmse:0.017925	validation_1-rmse:0.020287
# [59]	validation_0-rmse:0.017741	validation_1-rmse:0.020116
# [60]	validation_0-rmse:0.017601	validation_1-rmse:0.019994
# [61]	validation_0-rmse:0.017527	validation_1-rmse:0.019917
# [62]	validation_0-rmse:0.017475	validation_1-rmse:0.019879
# [63]	validation_0-rmse:0.017431	validation_1-rmse:0.01983
# [64]	validation_0-rmse:0.01735	validation_1-rmse:0.019759
# [65]	validation_0-rmse:0.017306	validation_1-rmse:0.019704
# [66]	validation_0-rmse:0.017241	validation_1-rmse:0.019637
# [67]	validation_0-rmse:0.017135	validation_1-rmse:0.019528
# [68]	validation_0-rmse:0.017099	validation_1-rmse:0.019498
# [69]	validation_0-rmse:0.017061	validation_1-rmse:0.019468
# [70]	validation_0-rmse:0.016991	validation_1-rmse:0.019405
# [71]	validation_0-rmse:0.016927	validation_1-rmse:0.019361
# [72]	validation_0-rmse:0.016864	validation_1-rmse:0.019292
# [73]	validation_0-rmse:0.016826	validation_1-rmse:0.019255
# [74]	validation_0-rmse:0.016735	validation_1-rmse:0.019165
# [75]	validation_0-rmse:0.016608	validation_1-rmse:0.019047
# [76]	validation_0-rmse:0.016582	validation_1-rmse:0.019024
# [77]	validation_0-rmse:0.016526	validation_1-rmse:0.019001
# [78]	validation_0-rmse:0.016485	validation_1-rmse:0.018956
# [79]	validation_0-rmse:0.016444	validation_1-rmse:0.018921
# [80]	validation_0-rmse:0.016342	validation_1-rmse:0.018836
# [81]	validation_0-rmse:0.01632	validation_1-rmse:0.01882
# [82]	validation_0-rmse:0.016263	validation_1-rmse:0.018757
# [83]	validation_0-rmse:0.016231	validation_1-rmse:0.018738
# [84]	validation_0-rmse:0.016111	validation_1-rmse:0.018617
# [85]	validation_0-rmse:0.016091	validation_1-rmse:0.018594
# [86]	validation_0-rmse:0.01599	validation_1-rmse:0.018509
# [87]	validation_0-rmse:0.015967	validation_1-rmse:0.018493
# [88]	validation_0-rmse:0.01595	validation_1-rmse:0.018471
# [89]	validation_0-rmse:0.015899	validation_1-rmse:0.018429
# [90]	validation_0-rmse:0.015876	validation_1-rmse:0.018416
# [91]	validation_0-rmse:0.015854	validation_1-rmse:0.018393
# [92]	validation_0-rmse:0.015801	validation_1-rmse:0.018358
# [93]	validation_0-rmse:0.015768	validation_1-rmse:0.018324
# [94]	validation_0-rmse:0.015759	validation_1-rmse:0.018321
# [95]	validation_0-rmse:0.015708	validation_1-rmse:0.018283
# [96]	validation_0-rmse:0.015688	validation_1-rmse:0.018272
# [97]	validation_0-rmse:0.015613	validation_1-rmse:0.0182
# [98]	validation_0-rmse:0.015593	validation_1-rmse:0.018184
# [99]	validation_0-rmse:0.015562	validation_1-rmse:0.018158
# [11:40:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:0.598844	validation_1-rmse:0.621781
# [1]	validation_0-rmse:0.584681	validation_1-rmse:0.607175
# [2]	validation_0-rmse:0.572847	validation_1-rmse:0.595423
# [3]	validation_0-rmse:0.558512	validation_1-rmse:0.579661
# [4]	validation_0-rmse:0.543305	validation_1-rmse:0.563518
# [5]	validation_0-rmse:0.531442	validation_1-rmse:0.551066
# [6]	validation_0-rmse:0.519415	validation_1-rmse:0.53828
# [7]	validation_0-rmse:0.506319	validation_1-rmse:0.525278
# [8]	validation_0-rmse:0.494491	validation_1-rmse:0.514699
# [9]	validation_0-rmse:0.485989	validation_1-rmse:0.50469
# [10]	validation_0-rmse:0.477483	validation_1-rmse:0.49693
# [11]	validation_0-rmse:0.472376	validation_1-rmse:0.491981
# [12]	validation_0-rmse:0.465775	validation_1-rmse:0.487964
# [13]	validation_0-rmse:0.459068	validation_1-rmse:0.481685
# [14]	validation_0-rmse:0.452921	validation_1-rmse:0.47619
# [15]	validation_0-rmse:0.445184	validation_1-rmse:0.469322
# [16]	validation_0-rmse:0.439915	validation_1-rmse:0.465765
# [17]	validation_0-rmse:0.435006	validation_1-rmse:0.462768
# [18]	validation_0-rmse:0.431252	validation_1-rmse:0.459912
# [19]	validation_0-rmse:0.425606	validation_1-rmse:0.453702
# [20]	validation_0-rmse:0.421786	validation_1-rmse:0.449797
# [21]	validation_0-rmse:0.417457	validation_1-rmse:0.446348
# [22]	validation_0-rmse:0.414656	validation_1-rmse:0.443078
# [23]	validation_0-rmse:0.410321	validation_1-rmse:0.439932
# [24]	validation_0-rmse:0.408783	validation_1-rmse:0.439565
# [25]	validation_0-rmse:0.405863	validation_1-rmse:0.437874
# [26]	validation_0-rmse:0.401789	validation_1-rmse:0.43386
# [27]	validation_0-rmse:0.399267	validation_1-rmse:0.431421
# [28]	validation_0-rmse:0.39654	validation_1-rmse:0.430443
# [29]	validation_0-rmse:0.393174	validation_1-rmse:0.427079
# [30]	validation_0-rmse:0.391086	validation_1-rmse:0.424515
# [31]	validation_0-rmse:0.386725	validation_1-rmse:0.420652
# [32]	validation_0-rmse:0.383917	validation_1-rmse:0.417777
# [33]	validation_0-rmse:0.381509	validation_1-rmse:0.416331
# [34]	validation_0-rmse:0.379626	validation_1-rmse:0.414212
# [35]	validation_0-rmse:0.375768	validation_1-rmse:0.410125
# [36]	validation_0-rmse:0.373012	validation_1-rmse:0.407778
# [37]	validation_0-rmse:0.370856	validation_1-rmse:0.405782
# [38]	validation_0-rmse:0.368832	validation_1-rmse:0.404652
# [39]	validation_0-rmse:0.367221	validation_1-rmse:0.402333
# [40]	validation_0-rmse:0.361653	validation_1-rmse:0.396019
# [41]	validation_0-rmse:0.35985	validation_1-rmse:0.393907
# [42]	validation_0-rmse:0.355328	validation_1-rmse:0.388737
# [43]	validation_0-rmse:0.353558	validation_1-rmse:0.388316
# [44]	validation_0-rmse:0.351661	validation_1-rmse:0.386885
# [45]	validation_0-rmse:0.350117	validation_1-rmse:0.385124
# [46]	validation_0-rmse:0.347006	validation_1-rmse:0.382762
# [47]	validation_0-rmse:0.342769	validation_1-rmse:0.378858
# [48]	validation_0-rmse:0.341099	validation_1-rmse:0.378514
# [49]	validation_0-rmse:0.337468	validation_1-rmse:0.375377
# [50]	validation_0-rmse:0.334441	validation_1-rmse:0.373748
# [51]	validation_0-rmse:0.333318	validation_1-rmse:0.372307
# [52]	validation_0-rmse:0.331153	validation_1-rmse:0.370669
# [53]	validation_0-rmse:0.328665	validation_1-rmse:0.36979
# [54]	validation_0-rmse:0.32513	validation_1-rmse:0.366045
# [55]	validation_0-rmse:0.32371	validation_1-rmse:0.365383
# [56]	validation_0-rmse:0.321129	validation_1-rmse:0.363159
# [57]	validation_0-rmse:0.319925	validation_1-rmse:0.362959
# [58]	validation_0-rmse:0.317411	validation_1-rmse:0.36026
# [59]	validation_0-rmse:0.316196	validation_1-rmse:0.359798
# [60]	validation_0-rmse:0.314474	validation_1-rmse:0.359544
# [61]	validation_0-rmse:0.311213	validation_1-rmse:0.356823
# [62]	validation_0-rmse:0.308482	validation_1-rmse:0.354645
# [63]	validation_0-rmse:0.307091	validation_1-rmse:0.353062
# [64]	validation_0-rmse:0.306062	validation_1-rmse:0.352782
# [65]	validation_0-rmse:0.305082	validation_1-rmse:0.351768
# [66]	validation_0-rmse:0.303443	validation_1-rmse:0.350459
# [67]	validation_0-rmse:0.301501	validation_1-rmse:0.348356
# [68]	validation_0-rmse:0.301125	validation_1-rmse:0.348027
# [69]	validation_0-rmse:0.29795	validation_1-rmse:0.346266
# [70]	validation_0-rmse:0.296751	validation_1-rmse:0.345154
# [71]	validation_0-rmse:0.295092	validation_1-rmse:0.34365
# [72]	validation_0-rmse:0.294475	validation_1-rmse:0.343008
# [73]	validation_0-rmse:0.291611	validation_1-rmse:0.341215
# [74]	validation_0-rmse:0.290143	validation_1-rmse:0.33996
# [75]	validation_0-rmse:0.289599	validation_1-rmse:0.338984
# [76]	validation_0-rmse:0.286879	validation_1-rmse:0.336262
# [77]	validation_0-rmse:0.28535	validation_1-rmse:0.335645
# [78]	validation_0-rmse:0.284108	validation_1-rmse:0.334641
# [79]	validation_0-rmse:0.282735	validation_1-rmse:0.333891
# [80]	validation_0-rmse:0.281612	validation_1-rmse:0.3331
# [81]	validation_0-rmse:0.280009	validation_1-rmse:0.33096
# [82]	validation_0-rmse:0.277539	validation_1-rmse:0.329449
# [83]	validation_0-rmse:0.275965	validation_1-rmse:0.327907
# [84]	validation_0-rmse:0.275011	validation_1-rmse:0.326795
# [85]	validation_0-rmse:0.274402	validation_1-rmse:0.326444
# [86]	validation_0-rmse:0.27223	validation_1-rmse:0.324842
# [87]	validation_0-rmse:0.270183	validation_1-rmse:0.323068
# [88]	validation_0-rmse:0.269473	validation_1-rmse:0.322142
# [89]	validation_0-rmse:0.268595	validation_1-rmse:0.321633
# [90]	validation_0-rmse:0.267688	validation_1-rmse:0.321015
# [91]	validation_0-rmse:0.265941	validation_1-rmse:0.320273
# [92]	validation_0-rmse:0.26441	validation_1-rmse:0.318866
# [93]	validation_0-rmse:0.263213	validation_1-rmse:0.318137
# [94]	validation_0-rmse:0.262401	validation_1-rmse:0.317616
# [95]	validation_0-rmse:0.261644	validation_1-rmse:0.317814
# [96]	validation_0-rmse:0.260621	validation_1-rmse:0.317254
# [97]	validation_0-rmse:0.259604	validation_1-rmse:0.316969
# [98]	validation_0-rmse:0.257863	validation_1-rmse:0.316279
# [99]	validation_0-rmse:0.257059	validation_1-rmse:0.316083
# [11:40:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:0.52162	validation_1-rmse:0.520998
# [1]	validation_0-rmse:0.470142	validation_1-rmse:0.469519
# [2]	validation_0-rmse:0.423877	validation_1-rmse:0.423235
# [3]	validation_0-rmse:0.382309	validation_1-rmse:0.381671
# [4]	validation_0-rmse:0.344951	validation_1-rmse:0.344271
# [5]	validation_0-rmse:0.311391	validation_1-rmse:0.310648
# [6]	validation_0-rmse:0.281274	validation_1-rmse:0.280484
# [7]	validation_0-rmse:0.254279	validation_1-rmse:0.25351
# [8]	validation_0-rmse:0.230118	validation_1-rmse:0.229289
# [9]	validation_0-rmse:0.208457	validation_1-rmse:0.207592
# [10]	validation_0-rmse:0.189061	validation_1-rmse:0.188113
# [11]	validation_0-rmse:0.171737	validation_1-rmse:0.170705
# [12]	validation_0-rmse:0.156302	validation_1-rmse:0.155172
# [13]	validation_0-rmse:0.142571	validation_1-rmse:0.141389
# [14]	validation_0-rmse:0.130332	validation_1-rmse:0.129108
# [15]	validation_0-rmse:0.11953	validation_1-rmse:0.118185
# [16]	validation_0-rmse:0.109943	validation_1-rmse:0.108575
# [17]	validation_0-rmse:0.101568	validation_1-rmse:0.100122
# [18]	validation_0-rmse:0.094198	validation_1-rmse:0.092702
# [19]	validation_0-rmse:0.087762	validation_1-rmse:0.086213
# [20]	validation_0-rmse:0.082103	validation_1-rmse:0.080514
# [21]	validation_0-rmse:0.077221	validation_1-rmse:0.075555
# [22]	validation_0-rmse:0.073028	validation_1-rmse:0.071309
# [23]	validation_0-rmse:0.069443	validation_1-rmse:0.067667
# [24]	validation_0-rmse:0.066396	validation_1-rmse:0.064568
# [25]	validation_0-rmse:0.063716	validation_1-rmse:0.061873
# [26]	validation_0-rmse:0.061537	validation_1-rmse:0.059662
# [27]	validation_0-rmse:0.059641	validation_1-rmse:0.057733
# [28]	validation_0-rmse:0.058093	validation_1-rmse:0.056174
# [29]	validation_0-rmse:0.056794	validation_1-rmse:0.054905
# [30]	validation_0-rmse:0.055655	validation_1-rmse:0.053767
# [31]	validation_0-rmse:0.054722	validation_1-rmse:0.052861
# [32]	validation_0-rmse:0.053954	validation_1-rmse:0.052105
# [33]	validation_0-rmse:0.05325	validation_1-rmse:0.051399
# [34]	validation_0-rmse:0.052695	validation_1-rmse:0.050855
# [35]	validation_0-rmse:0.052216	validation_1-rmse:0.050392
# [36]	validation_0-rmse:0.05185	validation_1-rmse:0.050036
# [37]	validation_0-rmse:0.051484	validation_1-rmse:0.049728
# [38]	validation_0-rmse:0.051196	validation_1-rmse:0.049462
# [39]	validation_0-rmse:0.05097	validation_1-rmse:0.049256
# [40]	validation_0-rmse:0.050792	validation_1-rmse:0.049093
# [41]	validation_0-rmse:0.050616	validation_1-rmse:0.048946
# [42]	validation_0-rmse:0.050389	validation_1-rmse:0.048868
# [43]	validation_0-rmse:0.050265	validation_1-rmse:0.048763
# [44]	validation_0-rmse:0.050132	validation_1-rmse:0.048664
# [45]	validation_0-rmse:0.049906	validation_1-rmse:0.048635
# [46]	validation_0-rmse:0.049822	validation_1-rmse:0.048558
# [47]	validation_0-rmse:0.049618	validation_1-rmse:0.048461
# [48]	validation_0-rmse:0.049442	validation_1-rmse:0.048413
# [49]	validation_0-rmse:0.049363	validation_1-rmse:0.048358
# [50]	validation_0-rmse:0.049292	validation_1-rmse:0.048295
# [51]	validation_0-rmse:0.04911	validation_1-rmse:0.048216
# [52]	validation_0-rmse:0.048974	validation_1-rmse:0.048111
# [53]	validation_0-rmse:0.048938	validation_1-rmse:0.048076
# [54]	validation_0-rmse:0.048893	validation_1-rmse:0.048028
# [55]	validation_0-rmse:0.048841	validation_1-rmse:0.047992
# [56]	validation_0-rmse:0.048769	validation_1-rmse:0.047904
# [57]	validation_0-rmse:0.048668	validation_1-rmse:0.047839
# [58]	validation_0-rmse:0.048586	validation_1-rmse:0.047763
# [59]	validation_0-rmse:0.048499	validation_1-rmse:0.047754
# [60]	validation_0-rmse:0.048432	validation_1-rmse:0.047715
# [61]	validation_0-rmse:0.048326	validation_1-rmse:0.04776
# [62]	validation_0-rmse:0.048292	validation_1-rmse:0.047726
# [63]	validation_0-rmse:0.048249	validation_1-rmse:0.047696
# [64]	validation_0-rmse:0.048154	validation_1-rmse:0.047637
# [65]	validation_0-rmse:0.048071	validation_1-rmse:0.047572
# [66]	validation_0-rmse:0.048039	validation_1-rmse:0.047551
# [67]	validation_0-rmse:0.047986	validation_1-rmse:0.047518
# [68]	validation_0-rmse:0.047914	validation_1-rmse:0.047473
# [69]	validation_0-rmse:0.047896	validation_1-rmse:0.047465
# [70]	validation_0-rmse:0.047877	validation_1-rmse:0.047448
# [71]	validation_0-rmse:0.047781	validation_1-rmse:0.047483
# [72]	validation_0-rmse:0.047723	validation_1-rmse:0.047423
# [73]	validation_0-rmse:0.047639	validation_1-rmse:0.047378
# [74]	validation_0-rmse:0.047593	validation_1-rmse:0.047359
# [75]	validation_0-rmse:0.04755	validation_1-rmse:0.047317
# [76]	validation_0-rmse:0.04742	validation_1-rmse:0.047289
# [77]	validation_0-rmse:0.047391	validation_1-rmse:0.047268
# [78]	validation_0-rmse:0.047321	validation_1-rmse:0.047222
# [79]	validation_0-rmse:0.047294	validation_1-rmse:0.047199
# [80]	validation_0-rmse:0.047215	validation_1-rmse:0.047171
# [81]	validation_0-rmse:0.047202	validation_1-rmse:0.047165
# [82]	validation_0-rmse:0.047124	validation_1-rmse:0.047176
# [83]	validation_0-rmse:0.04704	validation_1-rmse:0.047159
# [84]	validation_0-rmse:0.046992	validation_1-rmse:0.047135
# [85]	validation_0-rmse:0.046909	validation_1-rmse:0.047151
# [86]	validation_0-rmse:0.046854	validation_1-rmse:0.047111
# [87]	validation_0-rmse:0.04684	validation_1-rmse:0.047099
# [88]	validation_0-rmse:0.046822	validation_1-rmse:0.047085
# [89]	validation_0-rmse:0.046755	validation_1-rmse:0.047029
# [90]	validation_0-rmse:0.046708	validation_1-rmse:0.046967
# [91]	validation_0-rmse:0.046672	validation_1-rmse:0.04695
# [92]	validation_0-rmse:0.046588	validation_1-rmse:0.046877
# [93]	validation_0-rmse:0.04656	validation_1-rmse:0.046857
# [94]	validation_0-rmse:0.046472	validation_1-rmse:0.046864
# [95]	validation_0-rmse:0.04633	validation_1-rmse:0.046759
# [96]	validation_0-rmse:0.046257	validation_1-rmse:0.046736
# [97]	validation_0-rmse:0.046181	validation_1-rmse:0.046737
# [98]	validation_0-rmse:0.046135	validation_1-rmse:0.046709
# [99]	validation_0-rmse:0.046124	validation_1-rmse:0.046701
# [11:40:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:0.487254	validation_1-rmse:0.469505
# [1]	validation_0-rmse:0.4631	validation_1-rmse:0.446322
# [2]	validation_0-rmse:0.437114	validation_1-rmse:0.425522
# [3]	validation_0-rmse:0.4185	validation_1-rmse:0.40855
# [4]	validation_0-rmse:0.398168	validation_1-rmse:0.391802
# [5]	validation_0-rmse:0.381405	validation_1-rmse:0.378852
# [6]	validation_0-rmse:0.367835	validation_1-rmse:0.367334
# [7]	validation_0-rmse:0.353094	validation_1-rmse:0.355424
# [8]	validation_0-rmse:0.340585	validation_1-rmse:0.346024
# [9]	validation_0-rmse:0.330371	validation_1-rmse:0.339355
# [10]	validation_0-rmse:0.320841	validation_1-rmse:0.332489
# [11]	validation_0-rmse:0.312997	validation_1-rmse:0.324891
# [12]	validation_0-rmse:0.304286	validation_1-rmse:0.319544
# [13]	validation_0-rmse:0.29696	validation_1-rmse:0.314735
# [14]	validation_0-rmse:0.291051	validation_1-rmse:0.30956
# [15]	validation_0-rmse:0.284706	validation_1-rmse:0.304652
# [16]	validation_0-rmse:0.278684	validation_1-rmse:0.300146
# [17]	validation_0-rmse:0.272818	validation_1-rmse:0.296539
# [18]	validation_0-rmse:0.268295	validation_1-rmse:0.292208
# [19]	validation_0-rmse:0.262896	validation_1-rmse:0.289405
# [20]	validation_0-rmse:0.260087	validation_1-rmse:0.287302
# [21]	validation_0-rmse:0.255624	validation_1-rmse:0.283965
# [22]	validation_0-rmse:0.251603	validation_1-rmse:0.280839
# [23]	validation_0-rmse:0.249314	validation_1-rmse:0.279385
# [24]	validation_0-rmse:0.245275	validation_1-rmse:0.276257
# [25]	validation_0-rmse:0.24382	validation_1-rmse:0.275212
# [26]	validation_0-rmse:0.241223	validation_1-rmse:0.273442
# [27]	validation_0-rmse:0.238682	validation_1-rmse:0.271647
# [28]	validation_0-rmse:0.236316	validation_1-rmse:0.269311
# [29]	validation_0-rmse:0.235069	validation_1-rmse:0.268195
# [30]	validation_0-rmse:0.231954	validation_1-rmse:0.266314
# [31]	validation_0-rmse:0.230834	validation_1-rmse:0.265286
# [32]	validation_0-rmse:0.227074	validation_1-rmse:0.262875
# [33]	validation_0-rmse:0.226029	validation_1-rmse:0.26198
# [34]	validation_0-rmse:0.223487	validation_1-rmse:0.259415
# [35]	validation_0-rmse:0.222517	validation_1-rmse:0.258826
# [36]	validation_0-rmse:0.221693	validation_1-rmse:0.25808
# [37]	validation_0-rmse:0.220422	validation_1-rmse:0.2573
# [38]	validation_0-rmse:0.217855	validation_1-rmse:0.255277
# [39]	validation_0-rmse:0.217205	validation_1-rmse:0.254705
# [40]	validation_0-rmse:0.215608	validation_1-rmse:0.253267
# [41]	validation_0-rmse:0.214903	validation_1-rmse:0.25263
# [42]	validation_0-rmse:0.21338	validation_1-rmse:0.251314
# [43]	validation_0-rmse:0.212087	validation_1-rmse:0.250279
# [44]	validation_0-rmse:0.211496	validation_1-rmse:0.249737
# [45]	validation_0-rmse:0.21023	validation_1-rmse:0.248561
# [46]	validation_0-rmse:0.207534	validation_1-rmse:0.246939
# [47]	validation_0-rmse:0.206297	validation_1-rmse:0.246158
# [48]	validation_0-rmse:0.205517	validation_1-rmse:0.245713
# [49]	validation_0-rmse:0.202865	validation_1-rmse:0.243466
# [50]	validation_0-rmse:0.202418	validation_1-rmse:0.242938
# [51]	validation_0-rmse:0.201399	validation_1-rmse:0.242366
# [52]	validation_0-rmse:0.19968	validation_1-rmse:0.241254
# [53]	validation_0-rmse:0.197748	validation_1-rmse:0.23916
# [54]	validation_0-rmse:0.197364	validation_1-rmse:0.238673
# [55]	validation_0-rmse:0.195775	validation_1-rmse:0.237358
# [56]	validation_0-rmse:0.19489	validation_1-rmse:0.236784
# [57]	validation_0-rmse:0.193143	validation_1-rmse:0.23601
# [58]	validation_0-rmse:0.192385	validation_1-rmse:0.23556
# [59]	validation_0-rmse:0.191862	validation_1-rmse:0.235387
# [60]	validation_0-rmse:0.190116	validation_1-rmse:0.234602
# [61]	validation_0-rmse:0.188746	validation_1-rmse:0.234121
# [62]	validation_0-rmse:0.187325	validation_1-rmse:0.233505
# [63]	validation_0-rmse:0.186631	validation_1-rmse:0.233265
# [64]	validation_0-rmse:0.185289	validation_1-rmse:0.232501
# [65]	validation_0-rmse:0.184241	validation_1-rmse:0.231663
# [66]	validation_0-rmse:0.183292	validation_1-rmse:0.231529
# [67]	validation_0-rmse:0.18266	validation_1-rmse:0.230938
# [68]	validation_0-rmse:0.18239	validation_1-rmse:0.23064
# [69]	validation_0-rmse:0.181557	validation_1-rmse:0.229978
# [70]	validation_0-rmse:0.180774	validation_1-rmse:0.229391
# [71]	validation_0-rmse:0.180144	validation_1-rmse:0.228619
# [72]	validation_0-rmse:0.177893	validation_1-rmse:0.226673
# [73]	validation_0-rmse:0.176751	validation_1-rmse:0.226175
# [74]	validation_0-rmse:0.176222	validation_1-rmse:0.225501
# [75]	validation_0-rmse:0.176001	validation_1-rmse:0.22542
# [76]	validation_0-rmse:0.175791	validation_1-rmse:0.225098
# [77]	validation_0-rmse:0.174306	validation_1-rmse:0.223912
# [78]	validation_0-rmse:0.172451	validation_1-rmse:0.222175
# [79]	validation_0-rmse:0.171958	validation_1-rmse:0.222008
# [80]	validation_0-rmse:0.170214	validation_1-rmse:0.220524
# [81]	validation_0-rmse:0.169641	validation_1-rmse:0.219936
# [82]	validation_0-rmse:0.168451	validation_1-rmse:0.218496
# [83]	validation_0-rmse:0.166845	validation_1-rmse:0.21698
# [84]	validation_0-rmse:0.166646	validation_1-rmse:0.21672
# [85]	validation_0-rmse:0.166327	validation_1-rmse:0.216605
# [86]	validation_0-rmse:0.165165	validation_1-rmse:0.215792
# [87]	validation_0-rmse:0.164688	validation_1-rmse:0.215564
# [88]	validation_0-rmse:0.164515	validation_1-rmse:0.215517
# [89]	validation_0-rmse:0.163083	validation_1-rmse:0.214353
# [90]	validation_0-rmse:0.161866	validation_1-rmse:0.213766
# [91]	validation_0-rmse:0.160693	validation_1-rmse:0.212669
# [92]	validation_0-rmse:0.160408	validation_1-rmse:0.212681
# [93]	validation_0-rmse:0.159446	validation_1-rmse:0.211445
# [94]	validation_0-rmse:0.158406	validation_1-rmse:0.210401
# [95]	validation_0-rmse:0.157405	validation_1-rmse:0.209534
# [96]	validation_0-rmse:0.156578	validation_1-rmse:0.208833
# [97]	validation_0-rmse:0.155743	validation_1-rmse:0.208388
# [98]	validation_0-rmse:0.155031	validation_1-rmse:0.208583
# [99]	validation_0-rmse:0.154337	validation_1-rmse:0.208012
# [11:40:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:0.518781	validation_1-rmse:0.521091
# [1]	validation_0-rmse:0.467518	validation_1-rmse:0.469938
# [2]	validation_0-rmse:0.421427	validation_1-rmse:0.423944
# [3]	validation_0-rmse:0.380011	validation_1-rmse:0.382645
# [4]	validation_0-rmse:0.342789	validation_1-rmse:0.345572
# [5]	validation_0-rmse:0.309366	validation_1-rmse:0.312238
# [6]	validation_0-rmse:0.279319	validation_1-rmse:0.282267
# [7]	validation_0-rmse:0.252366	validation_1-rmse:0.255389
# [8]	validation_0-rmse:0.228208	validation_1-rmse:0.231299
# [9]	validation_0-rmse:0.206584	validation_1-rmse:0.209799
# [10]	validation_0-rmse:0.187201	validation_1-rmse:0.190501
# [11]	validation_0-rmse:0.169865	validation_1-rmse:0.17328
# [12]	validation_0-rmse:0.154399	validation_1-rmse:0.157875
# [13]	validation_0-rmse:0.14055	validation_1-rmse:0.144171
# [14]	validation_0-rmse:0.128201	validation_1-rmse:0.131987
# [15]	validation_0-rmse:0.117243	validation_1-rmse:0.12118
# [16]	validation_0-rmse:0.107569	validation_1-rmse:0.111596
# [17]	validation_0-rmse:0.099055	validation_1-rmse:0.103182
# [18]	validation_0-rmse:0.091469	validation_1-rmse:0.095752
# [19]	validation_0-rmse:0.084906	validation_1-rmse:0.089264
# [20]	validation_0-rmse:0.079035	validation_1-rmse:0.083512
# [21]	validation_0-rmse:0.073923	validation_1-rmse:0.078533
# [22]	validation_0-rmse:0.0696	validation_1-rmse:0.074294
# [23]	validation_0-rmse:0.065743	validation_1-rmse:0.070536
# [24]	validation_0-rmse:0.062545	validation_1-rmse:0.067403
# [25]	validation_0-rmse:0.059699	validation_1-rmse:0.064567
# [26]	validation_0-rmse:0.057384	validation_1-rmse:0.06229
# [27]	validation_0-rmse:0.055384	validation_1-rmse:0.060286
# [28]	validation_0-rmse:0.053587	validation_1-rmse:0.058548
# [29]	validation_0-rmse:0.052101	validation_1-rmse:0.057027
# [30]	validation_0-rmse:0.050879	validation_1-rmse:0.055821
# [31]	validation_0-rmse:0.049863	validation_1-rmse:0.054823
# [32]	validation_0-rmse:0.04904	validation_1-rmse:0.054004
# [33]	validation_0-rmse:0.04825	validation_1-rmse:0.053233
# [34]	validation_0-rmse:0.047647	validation_1-rmse:0.052618
# [35]	validation_0-rmse:0.047137	validation_1-rmse:0.052072
# [36]	validation_0-rmse:0.046644	validation_1-rmse:0.051565
# [37]	validation_0-rmse:0.046253	validation_1-rmse:0.051117
# [38]	validation_0-rmse:0.045958	validation_1-rmse:0.050786
# [39]	validation_0-rmse:0.045696	validation_1-rmse:0.050495
# [40]	validation_0-rmse:0.045489	validation_1-rmse:0.050272
# [41]	validation_0-rmse:0.045304	validation_1-rmse:0.05008
# [42]	validation_0-rmse:0.045118	validation_1-rmse:0.049837
# [43]	validation_0-rmse:0.044797	validation_1-rmse:0.049562
# [44]	validation_0-rmse:0.044604	validation_1-rmse:0.049387
# [45]	validation_0-rmse:0.04449	validation_1-rmse:0.049242
# [46]	validation_0-rmse:0.044358	validation_1-rmse:0.049064
# [47]	validation_0-rmse:0.04429	validation_1-rmse:0.048983
# [48]	validation_0-rmse:0.044211	validation_1-rmse:0.0489
# [49]	validation_0-rmse:0.044044	validation_1-rmse:0.048761
# [50]	validation_0-rmse:0.043977	validation_1-rmse:0.048683
# [51]	validation_0-rmse:0.043868	validation_1-rmse:0.048581
# [52]	validation_0-rmse:0.043783	validation_1-rmse:0.048473
# [53]	validation_0-rmse:0.043704	validation_1-rmse:0.048347
# [54]	validation_0-rmse:0.043608	validation_1-rmse:0.04827
# [55]	validation_0-rmse:0.043403	validation_1-rmse:0.048131
# [56]	validation_0-rmse:0.043334	validation_1-rmse:0.04806
# [57]	validation_0-rmse:0.043308	validation_1-rmse:0.048029
# [58]	validation_0-rmse:0.04312	validation_1-rmse:0.047902
# [59]	validation_0-rmse:0.043064	validation_1-rmse:0.047844
# [60]	validation_0-rmse:0.042988	validation_1-rmse:0.047779
# [61]	validation_0-rmse:0.042952	validation_1-rmse:0.047745
# [62]	validation_0-rmse:0.0428	validation_1-rmse:0.047639
# [63]	validation_0-rmse:0.04278	validation_1-rmse:0.047616
# [64]	validation_0-rmse:0.042728	validation_1-rmse:0.04756
# [65]	validation_0-rmse:0.042578	validation_1-rmse:0.047402
# [66]	validation_0-rmse:0.042444	validation_1-rmse:0.047226
# [67]	validation_0-rmse:0.042332	validation_1-rmse:0.047119
# [68]	validation_0-rmse:0.042307	validation_1-rmse:0.047092
# [69]	validation_0-rmse:0.042291	validation_1-rmse:0.047082
# [70]	validation_0-rmse:0.042111	validation_1-rmse:0.046824
# [71]	validation_0-rmse:0.041965	validation_1-rmse:0.046709
# [72]	validation_0-rmse:0.041932	validation_1-rmse:0.04667
# [73]	validation_0-rmse:0.041813	validation_1-rmse:0.046559
# [74]	validation_0-rmse:0.041768	validation_1-rmse:0.046528
# [75]	validation_0-rmse:0.041648	validation_1-rmse:0.046415
# [76]	validation_0-rmse:0.041599	validation_1-rmse:0.046381
# [77]	validation_0-rmse:0.041478	validation_1-rmse:0.046253
# [78]	validation_0-rmse:0.04144	validation_1-rmse:0.046209
# [79]	validation_0-rmse:0.041385	validation_1-rmse:0.046158
# [80]	validation_0-rmse:0.041291	validation_1-rmse:0.046044
# [81]	validation_0-rmse:0.041188	validation_1-rmse:0.045902
# [82]	validation_0-rmse:0.041112	validation_1-rmse:0.04583
# [83]	validation_0-rmse:0.041057	validation_1-rmse:0.045774
# [84]	validation_0-rmse:0.040967	validation_1-rmse:0.04568
# [85]	validation_0-rmse:0.040914	validation_1-rmse:0.045649
# [86]	validation_0-rmse:0.040814	validation_1-rmse:0.045546
# [87]	validation_0-rmse:0.040785	validation_1-rmse:0.045527
# [88]	validation_0-rmse:0.040754	validation_1-rmse:0.045499
# [89]	validation_0-rmse:0.040671	validation_1-rmse:0.045413
# [90]	validation_0-rmse:0.040635	validation_1-rmse:0.045398
# [91]	validation_0-rmse:0.040531	validation_1-rmse:0.045328
# [92]	validation_0-rmse:0.040451	validation_1-rmse:0.045243
# [93]	validation_0-rmse:0.040404	validation_1-rmse:0.045221
# [94]	validation_0-rmse:0.04036	validation_1-rmse:0.045186
# [95]	validation_0-rmse:0.04027	validation_1-rmse:0.045076
# [96]	validation_0-rmse:0.040237	validation_1-rmse:0.04504
# [97]	validation_0-rmse:0.040168	validation_1-rmse:0.044995
# [98]	validation_0-rmse:0.040085	validation_1-rmse:0.04494
# [99]	validation_0-rmse:0.040003	validation_1-rmse:0.044899
# [11:40:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:0.415023	validation_1-rmse:0.410067
# [1]	validation_0-rmse:0.403307	validation_1-rmse:0.396928
# [2]	validation_0-rmse:0.392498	validation_1-rmse:0.385717
# [3]	validation_0-rmse:0.383352	validation_1-rmse:0.375777
# [4]	validation_0-rmse:0.373935	validation_1-rmse:0.366748
# [5]	validation_0-rmse:0.366147	validation_1-rmse:0.359436
# [6]	validation_0-rmse:0.358106	validation_1-rmse:0.350441
# [7]	validation_0-rmse:0.352105	validation_1-rmse:0.345381
# [8]	validation_0-rmse:0.34568	validation_1-rmse:0.337933
# [9]	validation_0-rmse:0.338969	validation_1-rmse:0.330934
# [10]	validation_0-rmse:0.333907	validation_1-rmse:0.324977
# [11]	validation_0-rmse:0.329887	validation_1-rmse:0.321595
# [12]	validation_0-rmse:0.325299	validation_1-rmse:0.317021
# [13]	validation_0-rmse:0.321495	validation_1-rmse:0.312302
# [14]	validation_0-rmse:0.317308	validation_1-rmse:0.308685
# [15]	validation_0-rmse:0.312637	validation_1-rmse:0.303836
# [16]	validation_0-rmse:0.309576	validation_1-rmse:0.301554
# [17]	validation_0-rmse:0.30683	validation_1-rmse:0.298228
# [18]	validation_0-rmse:0.304633	validation_1-rmse:0.296591
# [19]	validation_0-rmse:0.300578	validation_1-rmse:0.292966
# [20]	validation_0-rmse:0.297697	validation_1-rmse:0.289688
# [21]	validation_0-rmse:0.296165	validation_1-rmse:0.288845
# [22]	validation_0-rmse:0.293102	validation_1-rmse:0.286587
# [23]	validation_0-rmse:0.291859	validation_1-rmse:0.285871
# [24]	validation_0-rmse:0.290341	validation_1-rmse:0.284279
# [25]	validation_0-rmse:0.289255	validation_1-rmse:0.283925
# [26]	validation_0-rmse:0.287914	validation_1-rmse:0.282818
# [27]	validation_0-rmse:0.287019	validation_1-rmse:0.28215
# [28]	validation_0-rmse:0.284554	validation_1-rmse:0.280031
# [29]	validation_0-rmse:0.283799	validation_1-rmse:0.279857
# [30]	validation_0-rmse:0.282648	validation_1-rmse:0.278735
# [31]	validation_0-rmse:0.281999	validation_1-rmse:0.278681
# [32]	validation_0-rmse:0.279195	validation_1-rmse:0.276934
# [33]	validation_0-rmse:0.276825	validation_1-rmse:0.274371
# [34]	validation_0-rmse:0.275725	validation_1-rmse:0.273081
# [35]	validation_0-rmse:0.273885	validation_1-rmse:0.271714
# [36]	validation_0-rmse:0.272898	validation_1-rmse:0.270812
# [37]	validation_0-rmse:0.271137	validation_1-rmse:0.269652
# [38]	validation_0-rmse:0.26838	validation_1-rmse:0.267504
# [39]	validation_0-rmse:0.266048	validation_1-rmse:0.265528
# [40]	validation_0-rmse:0.26562	validation_1-rmse:0.265526
# [41]	validation_0-rmse:0.26495	validation_1-rmse:0.265282
# [42]	validation_0-rmse:0.264344	validation_1-rmse:0.264982
# [43]	validation_0-rmse:0.262438	validation_1-rmse:0.263263
# [44]	validation_0-rmse:0.261834	validation_1-rmse:0.263085
# [45]	validation_0-rmse:0.261479	validation_1-rmse:0.263092
# [46]	validation_0-rmse:0.259027	validation_1-rmse:0.261309
# [47]	validation_0-rmse:0.258613	validation_1-rmse:0.261042
# [48]	validation_0-rmse:0.256539	validation_1-rmse:0.258755
# [49]	validation_0-rmse:0.255888	validation_1-rmse:0.258281
# [50]	validation_0-rmse:0.255112	validation_1-rmse:0.257643
# [51]	validation_0-rmse:0.254801	validation_1-rmse:0.257391
# [52]	validation_0-rmse:0.253532	validation_1-rmse:0.256287
# [53]	validation_0-rmse:0.252863	validation_1-rmse:0.255707
# [54]	validation_0-rmse:0.251647	validation_1-rmse:0.255315
# [55]	validation_0-rmse:0.251072	validation_1-rmse:0.25473
# [56]	validation_0-rmse:0.250317	validation_1-rmse:0.254274
# [57]	validation_0-rmse:0.250046	validation_1-rmse:0.254409
# [58]	validation_0-rmse:0.248648	validation_1-rmse:0.253583
# [59]	validation_0-rmse:0.24808	validation_1-rmse:0.253226
# [60]	validation_0-rmse:0.247577	validation_1-rmse:0.252805
# [61]	validation_0-rmse:0.245726	validation_1-rmse:0.250998
# [62]	validation_0-rmse:0.245245	validation_1-rmse:0.250667
# [63]	validation_0-rmse:0.244547	validation_1-rmse:0.249802
# [64]	validation_0-rmse:0.243265	validation_1-rmse:0.248392
# [65]	validation_0-rmse:0.242837	validation_1-rmse:0.248034
# [66]	validation_0-rmse:0.242648	validation_1-rmse:0.247971
# [67]	validation_0-rmse:0.242269	validation_1-rmse:0.247813
# [68]	validation_0-rmse:0.241998	validation_1-rmse:0.247618
# [69]	validation_0-rmse:0.241836	validation_1-rmse:0.247516
# [70]	validation_0-rmse:0.241448	validation_1-rmse:0.247388
# [71]	validation_0-rmse:0.24106	validation_1-rmse:0.247139
# [72]	validation_0-rmse:0.240009	validation_1-rmse:0.246452
# [73]	validation_0-rmse:0.238553	validation_1-rmse:0.245637
# [74]	validation_0-rmse:0.238102	validation_1-rmse:0.244887
# [75]	validation_0-rmse:0.237659	validation_1-rmse:0.244148
# [76]	validation_0-rmse:0.236406	validation_1-rmse:0.243157
# [77]	validation_0-rmse:0.235986	validation_1-rmse:0.242964
# [78]	validation_0-rmse:0.235636	validation_1-rmse:0.242824
# [79]	validation_0-rmse:0.23467	validation_1-rmse:0.242046
# [80]	validation_0-rmse:0.233543	validation_1-rmse:0.24172
# [81]	validation_0-rmse:0.232655	validation_1-rmse:0.241059
# [82]	validation_0-rmse:0.230983	validation_1-rmse:0.239951
# [83]	validation_0-rmse:0.230111	validation_1-rmse:0.239172
# [84]	validation_0-rmse:0.228441	validation_1-rmse:0.237146
# [85]	validation_0-rmse:0.228062	validation_1-rmse:0.236578
# [86]	validation_0-rmse:0.227358	validation_1-rmse:0.235737
# [87]	validation_0-rmse:0.226669	validation_1-rmse:0.235147
# [88]	validation_0-rmse:0.22638	validation_1-rmse:0.234963
# [89]	validation_0-rmse:0.225739	validation_1-rmse:0.234407
# [90]	validation_0-rmse:0.225249	validation_1-rmse:0.234155
# [91]	validation_0-rmse:0.225025	validation_1-rmse:0.234034
# [92]	validation_0-rmse:0.224296	validation_1-rmse:0.233171
# [93]	validation_0-rmse:0.223599	validation_1-rmse:0.232976
# [94]	validation_0-rmse:0.222975	validation_1-rmse:0.232806
# [95]	validation_0-rmse:0.222632	validation_1-rmse:0.232546
# [96]	validation_0-rmse:0.221951	validation_1-rmse:0.231851
# [97]	validation_0-rmse:0.221504	validation_1-rmse:0.231433
# [98]	validation_0-rmse:0.220273	validation_1-rmse:0.230915
# [99]	validation_0-rmse:0.220046	validation_1-rmse:0.230708
# [11:40:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:0.532063	validation_1-rmse:0.53285
# [1]	validation_0-rmse:0.47944	validation_1-rmse:0.4802
# [2]	validation_0-rmse:0.43213	validation_1-rmse:0.432882
# [3]	validation_0-rmse:0.389614	validation_1-rmse:0.390372
# [4]	validation_0-rmse:0.351397	validation_1-rmse:0.352087
# [5]	validation_0-rmse:0.31707	validation_1-rmse:0.317745
# [6]	validation_0-rmse:0.286253	validation_1-rmse:0.286966
# [7]	validation_0-rmse:0.258593	validation_1-rmse:0.259286
# [8]	validation_0-rmse:0.233781	validation_1-rmse:0.234422
# [9]	validation_0-rmse:0.211532	validation_1-rmse:0.212173
# [10]	validation_0-rmse:0.19162	validation_1-rmse:0.192248
# [11]	validation_0-rmse:0.173798	validation_1-rmse:0.17442
# [12]	validation_0-rmse:0.157864	validation_1-rmse:0.158493
# [13]	validation_0-rmse:0.143627	validation_1-rmse:0.144245
# [14]	validation_0-rmse:0.130969	validation_1-rmse:0.13158
# [15]	validation_0-rmse:0.119707	validation_1-rmse:0.120403
# [16]	validation_0-rmse:0.109738	validation_1-rmse:0.11042
# [17]	validation_0-rmse:0.100943	validation_1-rmse:0.101625
# [18]	validation_0-rmse:0.093156	validation_1-rmse:0.093902
# [19]	validation_0-rmse:0.086332	validation_1-rmse:0.087062
# [20]	validation_0-rmse:0.080336	validation_1-rmse:0.08107
# [21]	validation_0-rmse:0.075122	validation_1-rmse:0.075854
# [22]	validation_0-rmse:0.070595	validation_1-rmse:0.07137
# [23]	validation_0-rmse:0.066661	validation_1-rmse:0.067448
# [24]	validation_0-rmse:0.063295	validation_1-rmse:0.064099
# [25]	validation_0-rmse:0.060421	validation_1-rmse:0.061223
# [26]	validation_0-rmse:0.057963	validation_1-rmse:0.05877
# [27]	validation_0-rmse:0.055857	validation_1-rmse:0.056646
# [28]	validation_0-rmse:0.054122	validation_1-rmse:0.054893
# [29]	validation_0-rmse:0.052616	validation_1-rmse:0.053383
# [30]	validation_0-rmse:0.051384	validation_1-rmse:0.052153
# [31]	validation_0-rmse:0.050333	validation_1-rmse:0.051107
# [32]	validation_0-rmse:0.049432	validation_1-rmse:0.050193
# [33]	validation_0-rmse:0.048647	validation_1-rmse:0.04941
# [34]	validation_0-rmse:0.048063	validation_1-rmse:0.048828
# [35]	validation_0-rmse:0.047512	validation_1-rmse:0.048269
# [36]	validation_0-rmse:0.047051	validation_1-rmse:0.047804
# [37]	validation_0-rmse:0.046699	validation_1-rmse:0.047453
# [38]	validation_0-rmse:0.04639	validation_1-rmse:0.047146
# [39]	validation_0-rmse:0.046091	validation_1-rmse:0.046851
# [40]	validation_0-rmse:0.045883	validation_1-rmse:0.046646
# [41]	validation_0-rmse:0.045691	validation_1-rmse:0.046464
# [42]	validation_0-rmse:0.045527	validation_1-rmse:0.0463
# [43]	validation_0-rmse:0.045391	validation_1-rmse:0.046167
# [44]	validation_0-rmse:0.045289	validation_1-rmse:0.046065
# [45]	validation_0-rmse:0.045142	validation_1-rmse:0.045902
# [46]	validation_0-rmse:0.044981	validation_1-rmse:0.04577
# [47]	validation_0-rmse:0.044904	validation_1-rmse:0.045697
# [48]	validation_0-rmse:0.044825	validation_1-rmse:0.045617
# [49]	validation_0-rmse:0.044761	validation_1-rmse:0.045582
# [50]	validation_0-rmse:0.044691	validation_1-rmse:0.04551
# [51]	validation_0-rmse:0.044642	validation_1-rmse:0.04548
# [52]	validation_0-rmse:0.044539	validation_1-rmse:0.045378
# [53]	validation_0-rmse:0.044485	validation_1-rmse:0.045326
# [54]	validation_0-rmse:0.044416	validation_1-rmse:0.045269
# [55]	validation_0-rmse:0.044379	validation_1-rmse:0.045249
# [56]	validation_0-rmse:0.044303	validation_1-rmse:0.045196
# [57]	validation_0-rmse:0.044246	validation_1-rmse:0.045136
# [58]	validation_0-rmse:0.044161	validation_1-rmse:0.045047
# [59]	validation_0-rmse:0.044139	validation_1-rmse:0.045038
# [60]	validation_0-rmse:0.044086	validation_1-rmse:0.044996
# [61]	validation_0-rmse:0.044011	validation_1-rmse:0.044935
# [62]	validation_0-rmse:0.043949	validation_1-rmse:0.044902
# [63]	validation_0-rmse:0.043925	validation_1-rmse:0.044889
# [64]	validation_0-rmse:0.043893	validation_1-rmse:0.044851
# [65]	validation_0-rmse:0.043868	validation_1-rmse:0.044829
# [66]	validation_0-rmse:0.043805	validation_1-rmse:0.044768
# [67]	validation_0-rmse:0.043719	validation_1-rmse:0.044671
# [68]	validation_0-rmse:0.04369	validation_1-rmse:0.044642
# [69]	validation_0-rmse:0.04367	validation_1-rmse:0.044632
# [70]	validation_0-rmse:0.043617	validation_1-rmse:0.044591
# [71]	validation_0-rmse:0.04354	validation_1-rmse:0.044513
# [72]	validation_0-rmse:0.043474	validation_1-rmse:0.044453
# [73]	validation_0-rmse:0.043425	validation_1-rmse:0.044409
# [74]	validation_0-rmse:0.04337	validation_1-rmse:0.04434
# [75]	validation_0-rmse:0.043296	validation_1-rmse:0.044272
# [76]	validation_0-rmse:0.043275	validation_1-rmse:0.044257
# [77]	validation_0-rmse:0.043227	validation_1-rmse:0.044227
# [78]	validation_0-rmse:0.043142	validation_1-rmse:0.044162
# [79]	validation_0-rmse:0.043101	validation_1-rmse:0.044127
# [80]	validation_0-rmse:0.04303	validation_1-rmse:0.044048
# [81]	validation_0-rmse:0.04299	validation_1-rmse:0.044015
# [82]	validation_0-rmse:0.042973	validation_1-rmse:0.044021
# [83]	validation_0-rmse:0.042928	validation_1-rmse:0.043984
# [84]	validation_0-rmse:0.042875	validation_1-rmse:0.043936
# [85]	validation_0-rmse:0.042838	validation_1-rmse:0.043889
# [86]	validation_0-rmse:0.042756	validation_1-rmse:0.043812
# [87]	validation_0-rmse:0.042727	validation_1-rmse:0.043782
# [88]	validation_0-rmse:0.042654	validation_1-rmse:0.043735
# [89]	validation_0-rmse:0.04258	validation_1-rmse:0.043685
# [90]	validation_0-rmse:0.042541	validation_1-rmse:0.04365
# [91]	validation_0-rmse:0.042506	validation_1-rmse:0.043622
# [92]	validation_0-rmse:0.042471	validation_1-rmse:0.0436
# [93]	validation_0-rmse:0.042427	validation_1-rmse:0.043583
# [94]	validation_0-rmse:0.042397	validation_1-rmse:0.043552
# [95]	validation_0-rmse:0.042384	validation_1-rmse:0.043562
# [96]	validation_0-rmse:0.042331	validation_1-rmse:0.043516
# [97]	validation_0-rmse:0.042307	validation_1-rmse:0.043492
# [98]	validation_0-rmse:0.042278	validation_1-rmse:0.043478
# [99]	validation_0-rmse:0.042213	validation_1-rmse:0.043419
# Error 1 on : 0.000156 - 0.01898
# Error 1 off: 0.000242 - 0.00066
# Error 2 on : 0.06608 - 0.22156
# Error 2 off: 0.002127 - 0.002153
# Error 3 on : 0.02382 - 0.283379
# Error 3 off: 0.0016 - 0.001913
# Error 4 on : 0.04842 - 0.116422
# Error 4 off: 0.001782 - 0.003577

# %% [markdown]
# ## Creating the test dataframes with predicted humidity change

# %%
field_1_results_on = df[['timestamp','Soil humidity 1']][(df['segmentation']==1) & (df['train_test']==1) & (df['Irrigation field 1']==1)]
field_1_results_on['predictions'] = predictions_xgb_1_on

field_1_results_off = df[['timestamp','Soil humidity 1']][(df['segmentation']==1) & (df['train_test']==1) & (df['Irrigation field 1']==0)]
field_1_results_off['predictions'] = predictions_xgb_1_off

field_1_results = pd.concat([field_1_results_on,field_1_results_off])
field_1_results.sort_values(by=['timestamp'], inplace=True)

##

field_2_results_on = df[['timestamp','Soil humidity 2']][(df['segmentation']==3) & (df['train_test']==1) & (df['Irrigation field 2']==1)]
field_2_results_on['predictions'] = predictions_xgb_2_on

field_2_results_off = df[['timestamp','Soil humidity 2']][(df['segmentation']==3) & (df['train_test']==1) & (df['Irrigation field 2']==0)]
field_2_results_off['predictions'] = predictions_xgb_2_off

field_2_results = pd.concat([field_2_results_on,field_2_results_off])
field_2_results.sort_values(by=['timestamp'], inplace=True)

##

field_3_results_on = df[['timestamp','Soil humidity 3']][(df['segmentation']==2) & (df['train_test']==1) & (df['Irrigation field 3']==1)]
field_3_results_on['predictions'] = predictions_xgb_3_on

field_3_results_off = df[['timestamp','Soil humidity 3']][(df['segmentation']==2) & (df['train_test']==1) & (df['Irrigation field 3']==0)]
field_3_results_off['predictions'] = predictions_xgb_3_off

field_3_results = pd.concat([field_3_results_on,field_3_results_off])
field_3_results.sort_values(by=['timestamp'], inplace=True)

##

field_4_results_on = df[['timestamp','Soil humidity 4']][(df['segmentation']==3) & (df['train_test']==1) & (df['Irrigation field 4']==1)]
field_4_results_on['predictions'] = predictions_xgb_4_on

field_4_results_off = df[['timestamp','Soil humidity 4']][(df['segmentation']==3) & (df['train_test']==1) & (df['Irrigation field 4']==0)]
field_4_results_off['predictions'] = predictions_xgb_4_off

field_4_results = pd.concat([field_4_results_on,field_4_results_off])
field_4_results.sort_values(by=['timestamp'], inplace=True)

# %% [markdown]
# I have the predicted humidity change for each field. To calculate the soil humidity, I need to go over for each record, calculate the sum of predicted humidity change for this record and the previous humidity.
#
# In addtion to my predictions, I've added the average humidity change for irrigation on and off cases to the prediction. So that my predictions do not get too volatile.
#
# Since Zindi said we can use the peak humidity levels on the test data, when doing the one by one humidity calculation, if I encounter with one of those peak humidity moments, I've used that value as my new soil humidity. So I didn't use the future data, but I've just adjusted my predictions when I see an measured humidity.
#
# I feel this is more reasonable as your model will be predicting humidity for a field, but when you send a real measured value for a moment, than it should adjust itself according to that newly measured value.

# %%
import warnings
warnings.filterwarnings('ignore')

##################################### FIELD 1 #####################################

field_1_results_on = df[['timestamp','Soil humidity 1']][(df['segmentation']==1) & (df['train_test']==1) & (df['Irrigation field 1']==1)]
field_1_results_on['predictions'] = (predictions_xgb_1_on+3.5*df_1_train_on['target'].mean())/4.5

field_1_results_off = df[['timestamp','Soil humidity 1']][(df['segmentation']==1) & (df['train_test']==1) & (df['Irrigation field 1']==0)]
field_1_results_off['predictions'] = (predictions_xgb_1_off+3.5*df_1_train_off['target'].mean())/4.5

field_1_results = pd.concat([field_1_results_on,field_1_results_off])
field_1_results.sort_values(by=['timestamp'], inplace=True)

field_1_ek = df[['timestamp','Soil humidity 1']][(df['segmentation']==1) & (df['train_test']==0)][-1:]
field_1_ek['predictions'] = 0

field_1_results = pd.concat([field_1_ek,field_1_results])
field_1_results.reset_index(drop=True, inplace=True)
field_1_results['calculated_humidity'] = field_1_results['Soil humidity 1']

i = 1
i_max = field_1_results.index.max()

while i <= i_max:
    current_humidity = field_1_results['calculated_humidity'][i]
    
    if pd.isnull(current_humidity):
        previous_humidity = field_1_results['calculated_humidity'][i-1]
        difference = field_1_results['predictions'][i]
        value = previous_humidity + difference
        field_1_results['calculated_humidity'][i] = value
    else: 
        value = current_humidity
        field_1_results['calculated_humidity'][i] = value
               
    print('Field 1: '+str(i)+' / '+str(i_max)+'   ', end="\r")
    i = i+1


##################################### FIELD 2 #####################################

field_2_results_on = df[['timestamp','Soil humidity 2']][(df['segmentation']==3) & (df['train_test']==1) & (df['Irrigation field 2']==1)]
field_2_results_on['predictions'] = (predictions_xgb_2_on+3.5*df_2_train_on['target'].mean())/4.5

field_2_results_off = df[['timestamp','Soil humidity 2']][(df['segmentation']==3) & (df['train_test']==1) & (df['Irrigation field 2']==0)]
field_2_results_off['predictions'] = (predictions_xgb_2_off+3.5*df_2_train_off['target'].mean())/4.5

field_2_results = pd.concat([field_2_results_on,field_2_results_off])
field_2_results.sort_values(by=['timestamp'], inplace=True)

field_2_ek = df[['timestamp','Soil humidity 2']][(df['segmentation']==3) & (df['train_test']==0)][-1:]
field_2_ek['predictions'] = 0

field_2_results = pd.concat([field_2_ek,field_2_results])
field_2_results.reset_index(drop=True, inplace=True)
field_2_results['calculated_humidity'] = field_2_results['Soil humidity 2']

i = 1
i_max = field_2_results.index.max()

while i <= i_max:
    current_humidity = field_2_results['calculated_humidity'][i]
    
    if pd.isnull(current_humidity):
        previous_humidity = field_2_results['calculated_humidity'][i-1]
        difference = field_2_results['predictions'][i]
        value = previous_humidity + difference
        field_2_results['calculated_humidity'][i] = value
    else: 
        value = current_humidity
        field_2_results['calculated_humidity'][i] = value
               
    print('Field 2: '+str(i)+' / '+str(i_max)+'   ', end="\r")
    i = i+1

    

##################################### FIELD 3 #####################################

field_3_results_on = df[['timestamp','Soil humidity 3']][(df['segmentation']==2) & (df['train_test']==1) & (df['Irrigation field 3']==1)]
field_3_results_on['predictions'] = (predictions_xgb_3_on+3.5*df_3_train_on['target'].mean())/4.5

field_3_results_off = df[['timestamp','Soil humidity 3']][(df['segmentation']==2) & (df['train_test']==1) & (df['Irrigation field 3']==0)]
field_3_results_off['predictions'] = (predictions_xgb_3_off+3.5*df_3_train_off['target'].mean())/4.5

field_3_results = pd.concat([field_3_results_on,field_3_results_off])
field_3_results.sort_values(by=['timestamp'], inplace=True)

field_3_ek = df[['timestamp','Soil humidity 3']][(df['segmentation']==2) & (df['train_test']==0)][-1:]
field_3_ek['predictions'] = 0

field_3_results = pd.concat([field_3_ek,field_3_results])
field_3_results.reset_index(drop=True, inplace=True)
field_3_results['calculated_humidity'] = field_3_results['Soil humidity 3']

i = 1
i_max = field_3_results.index.max()

while i <= i_max:
    current_humidity = field_3_results['calculated_humidity'][i]
    
    if pd.isnull(current_humidity):
        previous_humidity = field_3_results['calculated_humidity'][i-1]
        difference = field_3_results['predictions'][i]
        value = previous_humidity + difference
        field_3_results['calculated_humidity'][i] = value
    else: 
        value = current_humidity
        field_3_results['calculated_humidity'][i] = value
               
    print('Field 3: '+str(i)+' / '+str(i_max)+'   ', end="\r")
    i = i+1


##################################### FIELD 4 #####################################

field_4_results_on = df[['timestamp','Soil humidity 4']][(df['segmentation']==3) & (df['train_test']==1) & (df['Irrigation field 4']==1)]
field_4_results_on['predictions'] = (predictions_xgb_4_on+3.5*df_4_train_on['target'].mean())/4.5

field_4_results_off = df[['timestamp','Soil humidity 4']][(df['segmentation']==3) & (df['train_test']==1) & (df['Irrigation field 4']==0)]
field_4_results_off['predictions'] = (predictions_xgb_4_off+3.5*df_4_train_off['target'].mean())/4.5

field_4_results = pd.concat([field_4_results_on,field_4_results_off])
field_4_results.sort_values(by=['timestamp'], inplace=True)

field_4_ek = df[['timestamp','Soil humidity 4']][(df['segmentation']==3) & (df['train_test']==0)][-1:]
field_4_ek['predictions'] = 0

field_4_results = pd.concat([field_4_ek,field_4_results])
field_4_results.reset_index(drop=True, inplace=True)
field_4_results['calculated_humidity'] = field_4_results['Soil humidity 4']

i = 1
i_max = field_4_results.index.max()

while i <= i_max:
    current_humidity = field_4_results['calculated_humidity'][i]
    
    if pd.isnull(current_humidity):
        previous_humidity = field_4_results['calculated_humidity'][i-1]
        difference = field_4_results['predictions'][i]
        value = previous_humidity + difference
        field_4_results['calculated_humidity'][i] = value
    else: 
        value = current_humidity
        field_4_results['calculated_humidity'][i] = value
               
    print('Field 4: '+str(i)+' / '+str(i_max)+'   ', end="\r")
    i = i+1
# Out:
# Field 4: 1748 / 1748

# %% [markdown]
# ## Exporting the results

# %%
df_export_1 = pd.DataFrame()
df_export_1['ID'] = field_1_results['timestamp'][1:]+' x Soil humidity 1'
df_export_1['Values'] = field_1_results['calculated_humidity'][1:]

df_export_2 = pd.DataFrame()
df_export_2['ID'] = field_2_results['timestamp'][1:-1]+' x Soil humidity 2'
df_export_2['Values'] = field_2_results['calculated_humidity'][1:-1]

df_export_3 = pd.DataFrame()
df_export_3['ID'] = field_3_results['timestamp'][1:]+' x Soil humidity 3'
df_export_3['Values'] = field_3_results['calculated_humidity'][1:]

df_export_4 = pd.DataFrame()
df_export_4['ID'] = field_4_results['timestamp'][1:-19]+' x Soil humidity 4'
df_export_4['Values'] = field_4_results['calculated_humidity'][1:-19]

df_export = pd.concat([df_export_1,df_export_2,df_export_3,df_export_4])
df_export.to_csv('Sertac_Ozker_submission.csv',index=False)
